# %%
x=50
y="KLH-BOWREMPET"
z=5.5
print(x," ", y, " ", z)
# Out:
# 50   KLH-BOWREMPET   5.5

# %%
myvar="KLH-BOWREMPET"
my_var="KLH-BOWREMPET"
_my_var="KLH-BOWREMPET"
myVar="KLH-BOWREMPET"
MYVAR="KLH-BOWREMPET"
myvar2="KLH-BOWREMPET"

# %%
name="Ravi"
AGE=20
Height=5.5
print(name)
print(AGE)
print(Height)
# Out:
# Ravi
# 20
# 5.5

# %%
x, y, z="Banana", "Orange", "Apple"
print(x)
print(y)
print(z)
# Out:
# Banana
# Orange
# Apple

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
print("Hello", "how are you?", sep="---")
print("hi", "hel", "hru", sep="**")
# Out:
# Hello---how are you?
# hi**hel**hru

# %%
var_name=input("Enter your name")
print(var_name)
# Out:
# Enter your nameHema
# Hema

# %%
a=int(input("Enter a value "))
b=int(input("Enter b value "))
c=int(input("Enter c value "))
print(a+b+c)
# Out:
# Enter a value 11
# Enter b value 43
# Enter c value 56
# 110

# %%
a=int(input('enter a - '))
print(a+10)
# Out:
# enter a - 22
# 32

# %%
a=10
b=20
if(a>b):
  print('a is the largest element')
else:
  print('a is smallest element')
# Out:
# a is smallest element

# %%
a=int(input('enter a - '))
b=int(input('enter b - '))
c=int(input('enter c - '))
if(a>b & a>c):
  print("a is the largest element")
elif(b>a & b>c):
  print("b is the largest element")
else:
  print("c is the largest element")
# Out:
# enter a - 22
# enter b - 34
# enter c - 43
# c is the largest element

# %%
x=1 #int
y=2.8 #float
z=1j #complex
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x=int(1)
y=int(2.8)
z=int("3")

print(x)
print(y)
print(z)
print("-----")

x=float(1)
y=float(2.8)
z=float("3")

print(x)
print(y)
print(z)
print("-----")

x=str(1)
y=str(2.8)
z=str(3)

print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3
# -----
# 1.0
# 2.8
# 3.0
# -----
# 1
# 2.8
# 3

# %%
b="KLH BOWREMPET"
print(b[2:5])
# Out:
# H B

# %%
B="KLH BOWREMPET"
print(B[:9])
# Out:
# KLH BOWRE

# %%
b="012345 6789"
print(b[5:])
# Out:
# 5 6789

# %%
B="KLH BOWREMPET"
print(B[-5:-2])
# Out:
# EMP

# %%
A="MY NAME IS CHAYATI HEMAVATHI"

print(A.lower())
print(A.find('T'))
print(A.swapcase())
print(A.title())
print(A.capitalize())
print(len(A))
print(A.upper())
# Out:
# my name is chayati hemavathi
# 16
# my name is chayati hemavathi
# My Name Is Chayati Hemavathi
# My name is chayati hemavathi
# 28
# MY NAME IS CHAYATI HEMAVATHI
