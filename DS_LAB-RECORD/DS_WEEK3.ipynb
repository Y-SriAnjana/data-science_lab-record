# %%
import numpy as np
from scipy.spatial import distance

pointA=np.array([2, 4, 6])
pointB=np.array([5, 1, 9])

euclidean_dst = distance.euclidean(pointA, pointB)
print("Euclidean Distance:", euclidean_dst)

similarity_euclidean = distance.cosine(pointA, pointB)
print("Simalarity Distance:", similarity_euclidean)
# Out:
# Euclidean Distance: 5.196152422706632
# Simalarity Distance: 0.12153793814103686

# %%
import numpy as np
from scipy.spatial import distance

pointA = np.array([2, 4, 6])
pointB = np.array([5, 1, 9])

# Euclidean Distance
euclidean_dist = distance.euclidean(pointA, pointB)
print("Euclidean Distance:", euclidean_dist)

# Similarity (inverse of distance)
similarity_euclidean = 1 / (1 + euclidean_dist)
print("Euclidean Similarity:", similarity_euclidean)
# Out:
# Euclidean Distance: 5.196152422706632
# Euclidean Similarity: 0.16139047779640892

# %%
manhattan_dst = distance.cityblock(pointA, pointB)
print("Manhattan Distance:", manhattan_dst)
#Similarity (inverse of distance)
similarity_manhattan = 1/(1+manhattan_dst)
print("Manhattan Similarity Distance:", similarity_manhattan)
# Out:
# Manhattan Distance: 9
# Manhattan Similarity Distance: 0.1

# %%
#Minkowski Distance with p=3
minkowski_dst = distance.minkowski(pointA, pointB, p=3)

#Similarity (inverse of distnce)
similarity_minkowski = 1/(1+minkowski_dst)

print("Minkowski Distance:", minkowski_dst)
print("Minkowski Similarity Distance:", similarity_minkowski)
# Out:
# Minkowski Distance: 4.3267487109222245
# Minkowski Similarity Distance: 0.1877317767871331

# %%
#Minkowski Distance with p=2
minkowski_dst = distance.minkowski(pointA, pointB, p=2)

#Similarity (inverse of distnce)
similarity_minkowski = 1/(1+minkowski_dst)

print("Minkowski Distance:", minkowski_dst)
print("Minkowski Similarity Distance:", similarity_minkowski)
# Out:
# Minkowski Distance: 5.196152422706632
# Minkowski Similarity Distance: 0.16139047779640892

# %%
#Minkowski Distance with p=1
minkowski_dst = distance.minkowski(pointA, pointB, p=1)

#Similarity (inverse of distnce)
similarity_minkowski = 1/(1+minkowski_dst)

print("Minkowski Distance:", minkowski_dst)
print("Minkowski Similarity Distance:", similarity_minkowski)
# Out:
# Minkowski Distance: 9.0
# Minkowski Similarity Distance: 0.1

# %%
import pandas as pd

#Example dataset
df = pd.DataFrame({
    'X': [10, 20, 30, 40, 50],
    'Y': [12, 24, 33, 45, 60]
})

#Pearson correlation matrix
corr_matrix = df.corr(method='pearson')
print("Pearson Correlation Matrix:\n", corr_matrix)
# Out:
# Pearson Correlation Matrix:
#            X         Y
# X  1.000000  0.996403
# Y  0.996403  1.000000

# %%
import pandas as pd

#for dataset
from scipy.stats import pearsonr

#Load the dataset
tips=pd.read_csv('tips.csv')

#Example: Pearson correlation between 'total_bill' and 'tip'
corr, _ = pearsonr(tips['total_bill'], tips['tip'])

print(f"Pearson Correlation coefficent: {corr}")
# Out:
# Pearson Correlation coefficent: 0.6757341092113647

# %%
import pandas as pd

#Load the dataset
tips=pd.read_csv('tips.csv')

# %%
import pandas as pd
from scipy.stats import spearmanr

df=pd.DataFrame({
    'X': [10, 20, 30, 40, 50],
    'Y': [12, 18, 33, 47, 55]
})

corr_value, p_value = spearmanr(df['X'], df['Y'])
print(f"Spearman Correlation Coefficient: {corr_value}")
print(f"p-value: {p_value}")
# Out:
# Spearman Correlation Coefficient: 0.9999999999999999
# p-value: 1.4042654220543672e-24

# %%
import pandas as pd
from scipy.stats import spearmanr
df=pd.read_csv('tips.csv')

corr_value, p_value = spearmanr(df['total_bill'], df['tip'])
print(f"Spearman Correlation Coefficient: {corr_value}")
print(f"p-value: {p_value}")
# Out:
# Spearman Correlation Coefficient: 0.6789681219001009
# p-value: 2.501158440923619e-34

# %%
def hamming_distance(str1, str2):

  #Ensure strings are of equal length
  if len(str1) != len(str2):
    raise ValueError("Strings must be of equal length")

  #Count differing positions
  return sum(ch1 != ch2 for ch1, ch2 in zip(str1, str2))

# Example usage
s1='Light'
s2='Lihgt'

dist=hamming_distance(s1, s2)
print(f"Hamming Distance between '{s1}' and '{s2}': {dist}")
# Out:
# Hamming Distance between 'Light' and 'Lihgt': 2

# %%
def jaccard_index(str1, str2):
  set1, set2 = set(str1.split()), set(str2.split())
  intersection = set1.intersection(set2)
  union = set1.union(set2)
  return len(intersection) / len(union)

#Example usage
s1 = "data science is fun"
s2 = "science makes data useful"

print("Jaccard index:", jaccard_index(s1, s2))
# Out:
# Jaccard index: 0.3333333333333333

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#Example sentences
s1 = "data science is fun"
s2 = "science makes data useful"

#Convert text to vector representation
vectorizer = CountVectorizer().fit([s1, s2])
vectors = vectorizer.transform([s1, s2])

#Calculate cosine similarity
cosine_sim = cosine_similarity(vectors[0], vectors[1])[0][0]
print("Cosine Similarity:", cosine_sim)
# Out:
# Cosine Similarity: 0.5

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#Example sentences
s1 = "data science is fun"
s2 = "science is the fact of the real world data"

#Convert text to vector representation
vectorizer = CountVectorizer().fit([s1, s2])
vectors = vectorizer.transform([s1, s2])

#Calculate cosine similarity
cosine_sim = cosine_similarity(vectors[0], vectors[1])[0][0]
print("Cosine Similarity:", cosine_sim)
# Out:
# Cosine Similarity: 0.45226701686664544

# %%
#Sequence-Based measures

def lcs_length(X, Y):
  m, n = len(X), len(Y)
  #Create a matrix to store lengths of LCS
  dp = [[0] * (n + 1) for _ in range(m + 1)]
  #Build the matrix
  for i in range(m):
    for j in range(n):
      if X[i] == Y[j]:
        dp[i+1][j+1] = dp[i][j] + 1
      else:
        dp[i+1][j+1] = max(dp[i][j+1], dp[i+1][j])
  return dp[m][n]
#Example usage
seq1 = "ABCDEF"
seq2 = "AEBDF"
length = lcs_length(seq1, seq2)
print(f"Longest Common Subsequence length between '{seq1}' and '{seq2}' : {length}")
# Out:
# Longest Common Subsequence length between 'ABCDEF' and 'AEBDF' : 4

# %%
def lcs_length(X, Y):
    m, n = len(X), len(Y)
    # Create a matrix to store lengths of LCS
    dp = [[0] * (n + 1) for _ in range(m + 1)]
    # Build the matrix
    for i in range(m):
        for j in range(n):
            if X[i] == Y[j]:
                dp[i+1][j+1] = dp[i][j] + 1
            else:
                dp[i+1][j+1] = max(dp[i][j+1], dp[i+1][j])
    return dp[m][n]
# Example usage
seq1 = "ABCDEF"
seq2 = "AEBDF"
length = lcs_length(seq1, seq2)
print(f"Longest Common Subsequence length between '{seq1}' and '{seq2}': {length}")
# Out:
# Longest Common Subsequence length between 'ABCDEF' and 'AEBDF': 4
